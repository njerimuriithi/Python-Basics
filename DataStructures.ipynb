# %% [markdown]
# ## Data Structures

# %% [markdown]
# ### <u>Data Structures</u>

# %% [markdown]
# 1. Create a list of 5 fruits and print the third fruit.

# %%
fruits =["Mango","Banana","Avocado","Kiwi","Watermelon"]
fruits[2]
# Out:
# 'Avocado'

# %% [markdown]
# 2. Create a dictionary with keys: name, age. Print the value of age.

# %%
NameAgeCollection={"Njeri":15}
print(NameAgeCollection["Njeri"])
# Out:
# 15

# %% [markdown]
# 3. Define a tuple with three numbers. Try modifying it. What happens?

# %%
#- Tuple is ordered and Unchangeable, allow duplicate values
numbers=(1,2,3,3)
numbers[0] =5
print(numbers[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 #- Tuple is ordered and Unchangeable, allow duplicate values
#       2 numbers=(1,2,3,3)
# ----> 3 numbers[0] =5
#       4 print(numbers[0])
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 4. Create a set from a list with duplicate values.

# %%
#sets  unordered, unchangeable, and do not allow duplicate values.
hobbies ={"walkinng","swimming","running","running"}
print(hobbies)
# Out:
# {'swimming', 'running', 'walkinng'}

# %% [markdown]
# ### <u>Challenge</u>
# #### Create a program that:
#
# - Takes 5 user inputs and stores them in a list
# - Converts the list into a set and prints the unique values

# %%
print("List 5 IT Careers")
careers = [input(),input(),input(),input(),input()]
print(careers)
print(set(careers))
# Out:
# List 5 IT Careers
# ['SE', 'QA', 'DSA', 'SE', 'QA']
# {'QA', 'DSA', 'SE'}
