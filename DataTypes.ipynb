# %% [markdown]
# ## Data Types

# %% [markdown]
# ### <u>Exercises<u>

# %% [markdown]
# 1. Print the type of 42, 3.14, and 'hello'.

# %%
print(type(42))
print(type(3.14))
print(type("hello"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 2. Convert a string '100' to an integer.

# %%
value ="100"
print(type(int(value)))
# Out:
# <class 'int'>

# %% [markdown]
# 3. Add an integer and a float together. What is the result?

# %%
value1 =100
value3  =1.2
result = value1+value3
print(result)
# Out:
# 101.2

# %% [markdown]
# 4. What happens when you try to multiply a string by a number?

# %%
text ="Hello"
num =2
multiplicationresult = text* num
print(multiplicationresult)
##This result multiplies the string value time the number used
# Out:
# HelloHello

# %% [markdown]
# ### <u> Challenge</u>
# ##### Write a program that:
#
# - Asks the user to enter two numbers (as strings)
# - Converts them to integers or floats
# - Prints their sum and type

# %%
print("Enter two numbers")
FirstNumber=str(input())
SecondNumber=str(input())
##print(type(FirstNumber),type(SecondNumber))
sumResults = int(FirstNumber)+int(SecondNumber)
print(sumResults,type(sumResults))
# Out:
# Enter two numbers
# 11 <class 'int'>
